# %%
import numpy as np

x = np.linspace(0, 5, 11)
y = x ** 2

# %%
#first plot
import matplotlib.pyplot as plt

#simple plot
plt.plot(x, y)

# %%
#creating labels x, y and title
plt.xlabel('eixo x')
plt.xlabel('eixo y')
plt.title('Título do gráfico')
plt.plot(y, x)
